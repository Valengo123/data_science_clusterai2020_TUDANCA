# %% [markdown]
# # ClusterAI 2020
# # Ciencia de Datos - Ingenieria Industrial UTN BA
# # Curso I5521
# # EDA: Nacidos Vivos registrados año 2018
#
# **Alumnos:**
# ###          Gomez Lucas
# ###          Sabini Manuel
# ###          Tudanca Valentin
#
# **Mentor:**
# ###          Lautaro Rshaid

# %% [markdown]
# El Dataset sobre el cual se realiza el siguiente Trabajo fue obtenido desde el portal de datos abiertos de la Nacion Argentina.
#
# El mismo fue confeccionado en el Año 2018 por el Ministerio de Salud. Dirección de Estadística e Información en Salud (DEIS)
#
# Nacidos vivos registrados año 2018
# Dataset: https://datos.gob.ar/dataset/salud-nacidos-vivos-registrados-por-jurisdiccion-residencia-madre---republica-argentina/archivo/salud_e1ae5157-2a94-4e2a-b147-43da647facc1

# %% [markdown]
# ### Librerias

# %%
#Importar paquetes de herramientas:

#Datos
import pandas as pd
import numpy as np
#Graficos 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset

# %%
ls
# Out:
#  El volumen de la unidad C es Acer
#  El número de serie del volumen es: 1807-B6DD
#
#  Directorio de C:\Users\vatud\Downloads
#
# 18/11/2020  21:40    <DIR>          .
# 18/11/2020  21:40    <DIR>          ..
# 11/11/2020  21:44    <DIR>          .ipynb_checkpoints
# 03/08/2020  21:07         1.285.011 02 Layout.pdf
# 23/10/2017  17:09         2.617.781 11 2014  Siderurgia.pdf
# 28/08/2020  20:24            84.272 117953250_1632820486864942_7097980643096041783_n.jpg
# 23/10/2017  17:08           263.600 12 2014 UTN Siderurgia Procesos.pdf
# 22/10/2017  22:58           553.891 13 2014 UTN Aceros Herramientas Rev 0.pdf
# 28/06/2017  15:52           107.676 1464623-hd-cookie-monster-wallpapers-free.jpg
# 11/06/2020  11:16         1.285.290 15 TUDANCA VALENTIN 4-26290958-0-0 (1).pdf
# 22/10/2017  22:58           311.221 17 2014 UTN Clasificación Aceros Rev E.pdf
# 23/10/2017  20:11         7.135.971 18 2014 UTN Aluminio y sus aleaciones.pdf
# 04/04/2020  17:21           436.933 1920px-Business_Model_Canvas.png
# 20/04/2020  20:18           100.403 1E655E9C78553C55312923EBB78291A3_labels.pdf
# 11/03/2020  23:43            26.713 1ra tanda mates .xlsx
# 22/10/2017  23:29         3.128.259 20 2014 UTN Titanio.pdf
# 27/10/2020  18:52         1.868.088 2016.zip
# 17/02/2020  21:45         1.795.483 2019_COBELOAGUSTIN_PPS3.pdf
# 03/03/2020  16:36           119.050 2019_TUDANCAVALENTIN_PPS1.pdf
# 28/04/2020  14:56           100.268 2019_TUDANCAVALENTIN_PPS2.pdf
# 05/05/2020  21:50         1.840.640 2019_TUDANCAVALENTIN_PPS3.doc
# 04/05/2020  14:05         1.881.895 2019_TUDANCAVALENTIN_PPS3.pdf
# 04/03/2020  17:55           133.968 2019_TUDANCAVALENTIN_PPS4.pdf
# 29/09/2020  20:57         2.840.055 2020_Accidentalidad.csv
# 03/10/2020  20:45         5.391.960 2020_seguiment-covid19-bcn.csv
# 26/02/2020  18:28           300.649 2020-02-26_133337.pdf
# 26/02/2020  18:28           282.320 2020-02-26_133514.pdf
# 29/09/2020  20:55            10.046 2020-09-29 - DsNación - Buenos Aires - Masculino - 18-75.csv
# 29/09/2020  20:53             7.952 2020-09-29 - DsNación - Entre Ríos - Masculino - 18-75.csv
# 15/10/2020  23:07            55.088 2020-09-listado-de-personal.csv
# 15/10/2020  23:07               306 2020-09-personal-por-provincia.csv
# 23/10/2017  16:49         3.767.592 21 2014 UTN Polímeros.pdf
# 29/09/2020  21:06            17.656 212086-0-oficinas-empleo.csv
# 08/11/2020  12:16    <DIR>          2do Parcial Manejo
# 18/06/2020  18:53            17.259 300000171858940-trazabilidad.pdf
# 09/09/2020  19:21            24.442 40101458519_200909190559.pdf
# 12/11/2020  21:26            85.754 4734ffe8-9f84-46e8-900c-3242844d4706.jpeg
# 20/07/2020  23:48        11.597.911 5. TP. Anual - CleanBin - Entrega5.docx
# 13/04/2020  14:43           503.473 6517-41636450_24_3_2020.pdf
# 05/07/2020  20:13            22.615 685640-mla31095163706_062019-o-f5f174e263c9e9604815638266060879-640-0.jpg
# 07/04/2020  11:13            22.108 92563073_3667359786669033_6949714997161230336_n.jpg
# 15/04/2020  15:39         5.379.292 92849780_561358264503259_7391502608902389760_n.mp4
# 15/04/2020  15:08         2.335.666 92883992_238624774211319_2075617989693038944_n.mp4
# 12/05/2020  14:31            15.219 93152064_00242646499 (1).pdf
# 12/05/2020  14:31            15.219 93152064_00242646499.pdf
# 15/07/2020  12:53            65.878 93152064_00242646499_209.pdf
# 12/05/2020  14:30            15.155 93152064_00242646499_48.pdf
# 28/05/2020  20:35            15.280 93152064_00242646499_79 (1).pdf
# 29/05/2020  12:07            15.280 93152064_00242646499_79 (2).pdf
# 12/05/2020  14:25            15.280 93152064_00242646499_79.pdf
# 15/04/2020  15:11         2.557.322 93755268_1892314207565941_6129486052692415750_n.mp4
# 03/10/2020  20:28            96.825 AccidentesBicicletas_2018.xlsx
# 24/10/2020  08:41        84.125.825 aclImdb_v1.tar.gz
# 03/04/2020  11:10           778.066 Aging  Marzo cerrado.xls
# 05/05/2020  11:11           749.792 Aging Abril Cerrado.xls
# 03/10/2020  08:16           257.211 AILucasGomez-main.zip
# 01/04/2020  18:22        30.340.873 Algotevaaservir.rar
# 15/10/2020  23:10            44.190 alumnos-matriculados-eoi_2012.csv
# 21/08/2020  22:48       490.200.880 Anaconda3-2020.07-Windows-x86_64.exe
# 26/05/2020  09:45    <DIR>          Analítico de Secundaria
# 01/06/2020  12:25         2.675.467 Antigüedad de DeudaV3.xlsx
# 02/07/2020  11:12           957.719 Antigüedad Deuda Junio cerrado.xls
# 01/06/2020  10:37           743.353 Antigüedad Deuda Mayo cerrado.xls
# 07/06/2020  18:08             9.133 Aprox edificios .xlsx
# 10/05/2020  10:34           666.808 Apunte clase mantenimiento (1).docx
# 29/09/2020  21:01            21.238 AREAS_DEPORTIVAS_2020.xlsx
# 15/11/2020  19:14           406.194 arroz.csv
# 03/10/2020  20:18        32.593.407 BICICLETAS_2019.xlsx
# 12/11/2020  22:28            89.434 c6101449-b564-4ae4-a580-6be653fedb21.jpeg
# 23/09/2020  20:14           213.662 cajeros-automaticos.csv
# 12/09/2020  20:49           234.117 Calculo con Load Bar (1).pdf
# 17/04/2020  18:04           234.117 Calculo con Load Bar.pdf
# 03/11/2020  21:59            11.651 Calculo Costo de Expo.xlsx
# 26/04/2020  21:46            12.710 Calculo MG.xlsx
# 08/04/2020  11:34            68.474 Canvas Lámpara Gravedad.docx
# 15/11/2020  19:23         1.705.462 carnica-vacuna.csv
# 10/11/2020  20:04            18.412 CASO COMBINADO.xlsx
# 01/05/2020  13:42       116.031.435 catalogo-ley-isover.pdf
# 20/06/2020  19:06            25.402 Choice - 1er Parcial Manejo - Te vamos a coger pelado puto.docx
# 22/06/2020  09:56           119.616 Choice - 1er Parcial Manejo - Te vamos a coger pelado puto.pdf
# 03/10/2020  10:18        43.462.544 CitrixReceiver.exe
# 29/08/2020  08:47    <DIR>          clase_01-master
# 29/08/2020  08:36         1.464.420 clase_01-master.zip
# 04/09/2020  22:49         2.334.338 clase_02-master.zip
# 19/09/2020  09:05         3.578.447 clase_03-master.zip
# 15/11/2020  20:53    <DIR>          Cluster Ai
# 11/11/2020  22:41            99.233 clusterai_2019_parcial_practico (1).ipynb
# 14/11/2020  17:00           126.666 clusterai_2019_parcial_practico (2).ipynb
# 11/11/2020  22:48            79.976 clusterai_2019_parcial_practico.ipynb
# 22/08/2020  10:03         3.598.159 clusterai_2020_clase_00-master.zip
# 05/11/2020  22:38        19.765.958 clusterai_2020_clase00-fusionado.pdf
# 02/10/2020  17:16           408.805 clusterai_2020_clase04_regresion_airbnb_london.ipynb
# 31/10/2020  08:51         1.689.077 clusterai_2020_clase10_neural_networks.pdf
# 08/10/2020  20:29    <DIR>          ClusterAI_2020_Ejercicios-master
# 08/10/2020  20:26           455.147 ClusterAI_2020_Ejercicios-master.zip
# 14/11/2020  18:04            60.006 clusterai_2020_parcial.ipynb
# 14/11/2020  13:31             5.149 clusterai_2020_parcial_practico.ipynb
# 15/11/2020  01:08            60.949 clusterai_2020_parcial_practico__Valentin_Tudanca.ipynb
# 15/11/2020  18:20            61.239 clusterai_2020_parcial_practico_Grupo14__Valentin_Tudanca.ipynb
# 26/09/2020  08:40        30.485.818 clusterai_2020-master (1).zip
# 03/10/2020  07:59        31.072.721 clusterai_2020-master (2).zip
# 10/10/2020  08:19        23.845.272 clusterai_2020-master (3).zip
# 17/10/2020  10:08        23.831.406 clusterai_2020-master (4).zip
# 14/11/2020  10:04        31.014.706 clusterai_2020-master (5).zip
# 31/10/2020  10:43        28.323.439 clusterai_2020-master (6).zip
# 19/09/2020  09:51        13.398.453 clusterai_2020-master.zip
# 03/10/2020  09:14    <DIR>          clusterai_clase05-master
# 03/10/2020  09:12           276.117 clusterai_clase05-master.zip
# 29/10/2020  23:10            59.328 clusterai_eda (Regresion MAl hecha).ipynb
# 18/11/2020  21:39           557.131 clusterai_Nombre_apellido_EDA.ipynb
# 18/11/2020  21:40           145.589 clusterai_Nombre_apellido_Machine_Learningv2.ipynb
# 16/11/2020  19:20           426.624 clusterai_TP_eda+SVM v2 (1).ipynb
# 16/11/2020  19:17           426.624 clusterai_TP_eda+SVM v2.ipynb
# 16/11/2020  22:56           101.586 clusterai_TP_eda+SVM v3.ipynb
# 17/11/2020  18:34           562.714 clusterai_TP_eda+SVM v5.ipynb
# 11/11/2020  20:06           304.422 clusterai_TP_eda+SVM.ipynb
# 18/11/2020  21:39           499.559 clusterai2020_apellido_reporte v1 (1).docx
# 18/11/2020  19:19           499.559 clusterai2020_apellido_reporte v1.docx
# 17/10/2020  10:06           158.483 clusterai2020_clase08_House_Price_prediction.zip
# 14/11/2020  19:43           131.475 clusterai2020_parcialpractico_grupo14_Lucas_Gomez.ipynb
# 14/11/2020  19:26            33.889 clusterai2020_parcialpractico_grupo14_Manuel_Sabini.ipynb
# 15/11/2020  21:07           584.292 clusterai2020_poster_template.pptx
# 15/10/2020  23:09            99.356 cobros-pagos-bienes-servicios.csv
# 14/06/2020  12:53         4.578.958 Com. Ex. Trabajo Práctico Tupperware V1.docx
# 27/10/2020  20:52         7.563.552 Com. Ex. Trabajo Práctico Tupperware V4.docx
# 10/11/2020  20:05            50.402 comex (1).xlsx
# 12/11/2020  23:31         5.133.843 Comex 2do Parcial (1).pdf
# 12/11/2020  23:30         5.133.843 Comex 2do Parcial.pdf
# 12/11/2020  23:48            52.351 comex V1.xlsx
# 06/11/2020  19:38            50.402 comex.xlsx
# 10/06/2020  10:01            26.770 COMPILADO DE PREGUNTAS MANEJO DE MATERIALES (1).docx
# 08/11/2020  10:28            21.632 COMPILADO DE PREGUNTAS MANEJO DE MATERIALES.docx
# 08/11/2020  09:54         1.231.079 COMPILADO PREGUNTAS 2DO PARCIAL- VOL 2 (1).pdf
# 08/11/2020  09:51         1.231.079 COMPILADO PREGUNTAS 2DO PARCIAL- VOL 2.pdf
# 09/11/2020  17:18         1.473.832 COMPILADO PREGUNTAS 2DO PARCIAL- VOL 2-fusionado.pdf
# 25/09/2020  21:20            45.386 compras-de-consumidores-de-glp.csv
# 14/11/2020  18:01           124.928 Concrete_Data.xls
# 16/09/2020  16:42            40.072 constanciadecuil-20385713712.pdf
# 10/10/2020  09:47           789.699 Consumo Gratis abril.pdf.pdf
# 03/08/2020  23:51            19.374 Consumo MP Inyectora V2.xlsx
# 23/10/2020  19:32           635.815 CONTRATOS Y DOCUMENTOS.pdf
# 10/11/2020  20:05           390.932 Costo de  exportacio´n (1) (1).pdf
# 06/11/2020  19:38           390.932 Costo de  exportacio´n (1).pdf
# 17/07/2020  18:13            96.548 Costos y Presu Calculadora (1).xlsx
# 17/07/2020  18:11            96.548 Costos y Presu Calculadora.xlsx
# 31/07/2020  12:52            93.966 Cotizacion 28-7.jpg
# 31/07/2020  12:39           447.788 Cotizacion 28-7.pptx
# 31/10/2020  21:06       295.325.309 Crash Team Racing [U] [SCUS-94426].rar
# 26/09/2020  08:41            19.635 CRP_628697006_20200925171257.PDF
# 23/03/2020  19:04    <DIR>          cs
# 22/03/2020  18:51       329.320.412 cs.zip
# 31/08/2020  15:08            99.121 CV Valentin Tudanca .docx
# 18/08/2020  11:29           704.425 CV Valentin Tudanca .pdf
# 31/03/2020  17:49            22.300 desinfectantetelefonos.jpg
# 29/06/2020  11:01            63.053 Diagrama en Bloques (1).docx
# 30/06/2020  01:13            61.964 Diagrama en Bloques.docx
# 15/11/2020  19:20           156.274 diccionario-de-variables.csv
# 03/08/2020  23:51         1.183.325 Dim T-E-F.xlsx
# 08/11/2020  16:09           354.858 Dimensionaminto Financiero - Grupo 9 - V4 (1).xlsx
# 25/10/2020  20:23           345.006 Dimensionaminto Financiero - Grupo 9 - V4.xlsx
# 01/04/2017  01:10        68.815.816 DJ3510_1315-1.exe
# 15/06/2020  09:45         1.181.001 Documento sin título.pdf
# 08/11/2020  09:00         1.263.423 Documentos escaneados.pdf
# 10/10/2020  08:18         1.416.977 drive-download-20201010T111823Z-001.zip
# 01/11/2020  10:19           558.958 Ejemplo rcm 1.docx
# 12/11/2020  23:48            40.194 Ejer1.xlsx
# 17/07/2020  19:13           195.547 Ejercicio Costos Tudanca.pdf
# 10/05/2020  12:51            72.891 Ejercicio Parcial Nivelatorio de Presupuestos.jpeg
# 29/10/2020  20:49            92.080 Ejercicio Practica ML Strategy (1).ipynb
# 24/10/2020  08:58            91.993 Ejercicio Practica ML Strategy.ipynb
# 19/06/2020  17:13         2.666.513 EJERCICIO PRIMER PARCIAL.docx
# 10/05/2020  10:34            23.885 Ejercicios (2).docx
# 02/11/2020  18:50           256.182 Ejercicios a resolver en clase - 2020 (1).xlsx
# 02/11/2020  18:32         4.846.434 Ejercicios belu pulella.pdf
# 11/07/2020  17:40           658.693 Ejercicios Costos de importacion.xlsx
# 11/07/2020  17:40            20.990 Ejercicios costos.xlsx
# 13/07/2020  19:17            54.640 Ejercicios de INCOTERMS.xlsx
# 14/07/2020  16:06            85.208 Ejercicios de practica INCOTERMS 2020.pdf
# 13/07/2020  19:17           576.691 Ejercicios Importacion.xlsx
# 11/10/2020  21:17           169.509 Ejercicios_Clase00.ipynb
# 14/05/2020  17:08            52.383 elegir-bien-las-frutas-y-verduras-655x368.jpg
# 03/08/2020  20:37           259.582 Entrada Correa.png
# 20/10/2020  20:03           107.295 Entrega Dim Economico Financiero ARREGLADO.xlsx
# 07/05/2020  18:20           499.087 Entrevista Juan Amabile 1.mp3
# 07/05/2020  18:22           939.198 Entrevista Juan Amabile 2.mp3
# 07/05/2020  18:24           763.864 Entrevista Juan Amabile 3.mp3
# 19/05/2020  21:00        44.081.152 EpicInstaller-10.15.2.msi
# 14/07/2020  15:59           253.002 Esquema incoterms.pdf
# 17/02/2020  21:46           305.781 Esquema SDP.pptx
# 18/08/2020  22:35            19.989 Estructura de costos mtm.docx
# 26/05/2020  18:55           369.292 Estudios de Mercado.pptx
# 26/05/2020  18:55           593.792 Evaluación y Gestión de Proyectos.pptx
# 16/11/2020  20:44        15.828.888 export_nacidos.csv
# 15/10/2020  23:08            25.675 exportaciones-por-paises-regiones-anual.csv
# 30/03/2020  18:28            97.962 F-01-10-Leyes de Murphy.pdf
# 23/06/2020  19:12           151.972 f8108399b661958192366b165e84383d.png
# 13/07/2020  12:06           154.261 Factura traslado.jpg
# 05/10/2020  19:07           136.131 Factura_B_00005-00980935 (1).pdf
# 04/10/2020  21:25           136.131 Factura_B_00005-00980935.pdf
# 14/04/2020  11:34        60.202.670 Fliess - Estabilidad Tomo I.rar
# 14/04/2020  11:34        10.482.632 Fliess - Estabilidad Tomo II.rar
# 04/05/2020  10:06        12.515.496 Folleto Digital tromen.pdf
# 17/02/2020  22:30            36.864 Formato Presentación Trabajos COINI 2013.doc
# 11/09/2020  22:24            20.791 formularioepp.xlsx
# 10/08/2020  11:43            60.216 Foro unidad 2.docx
# 08/11/2020  12:20        18.402.968 Fusionado 2do Parcial.pdf
# 31/08/2020  17:08            56.264 G4-20-09-MAIL GASTOS AGO.pdf
# 09/08/2020  12:08           674.751 Gancho.png
# 08/06/2020  09:57         2.368.603 G-U01-01 Planeacio´n de Instalaciones  Intralogi´stica.pdf
# 30/03/2020  19:50           812.429 G-U02-01 Localización de Plantas.pdf
# 06/04/2020  19:06         1.003.433 G-U02-02 Localizacion de Plantas (1).pdf
# 06/04/2020  19:05         1.003.433 G-U02-02 Localizacion de Plantas.pdf
# 10/06/2020  10:21         3.217.450 G-U03-01 Edificios Industriales (1).pdf
# 20/04/2020  10:56         3.217.450 G-U03-01 Edificios Industriales.pdf
# 11/06/2020  15:03         1.868.253 G-U04-01 Distribucio´n de Plantas (1).pdf
# 20/06/2020  20:09         1.868.253 G-U04-01 Distribucio´n de Plantas (2).pdf
# 20/04/2020  10:55         1.868.253 G-U04-01 Distribucio´n de Plantas.pdf
# 17/06/2020  10:40         1.242.492 G-U05-03 Disen~o _ dimensionamiento de almacenes (1).pdf
# 17/06/2020  10:38         1.242.492 G-U05-03 Disen~o _ dimensionamiento de almacenes.pdf
# 17/06/2020  10:51         2.117.025 G-U05-04 Sistemas de almacenaje.pdf
# 07/11/2020  16:18         3.022.676 G-U06-01 Transportes Externos a Planta.pdf
# 31/08/2020  17:38           963.628 G-U08-01 Colchon de aire.pdf
# 07/11/2020  15:14         1.357.578 G-U08-03 Transportadores Aereos.pdf
# 07/11/2020  15:13         1.203.342 G-U08-05 Elementos para elevacio´n de Carga.pdf
# 14/07/2020  16:15           333.159 Guia de ejercicios de importación .pdf
# 02/06/2020  19:45           311.426 Guía para la certificación IACSA.pdf
# 12/04/2020  17:07           443.624 Gui´a para la elaboracio´n del Proyecto Final v17 (1).pdf
# 09/04/2017  22:14            25.600 gymVal17.xls
# 03/10/2020  21:05            13.771 H.1.1.Total Pais. Titulares de derecho de la AUH. Hijo e Hijo Discapacitado.xlsx
# 26/06/2020  12:10           637.015 H84a7606b4f134ccd8b1567c1e9c1f818A.png
# 20/08/2019  23:04     1.354.811.392 HBCD_PE_x64.iso
# 21/09/2020  22:06        46.950.032 HL-L2360DW-inst-D1-US3.EXE
# 31/03/2020  17:47            19.935 ideasinnovadorasmaceta-221x300.jpg
# 12/06/2020  11:38         8.799.716 ilovepdf_merged.pdf
# 18/06/2020  23:10            25.068 image (1).png
# 18/06/2020  23:10           105.325 image.png
# 29/06/2020  09:42             7.511 images.jpeg
# 05/04/2017  21:03         3.713.689 IMG_20170119_214630531_HDR.jpg
# 03/06/2020  19:07            11.288 IMG-20131202-WA0016.jpg
# 13/07/2020  19:17           153.695 Incoterms.xlsx
# 11/09/2020  22:25         1.674.076 Industria de inyección plástica.pdf
# 22/05/2018  17:02    <DIR>          install
# 06/08/2020  23:45           761.242 Instructivo.pdf
# 14/11/2020  10:41         3.156.137 Instructivo-Beneficio Kit de Tecnología.pdf
# 26/09/2020  01:17             5.107 iris.csv
# 04/06/2020  20:17         9.707.037 iSlim310W7.zip
# 03/10/2020  21:10            78.100 ISSFinanciero2sem2019.xlsx
# 09/11/2020  16:26            39.604 jca.jpg
# 10/08/2020  21:01           542.568 Justificación mtm.docx
# 31/10/2020  08:42           605.361 keras-2.3.1-py37h21ff451_0.tar.bz2
# 31/10/2020  08:37            30.493 keras-2.4.3-py_0.tar.bz2
# 21/06/2020  15:40         5.099.610 La oveja oscar aparece de nuevo.mp4
# 21/06/2020  16:09         2.155.268 La oveja oscar con bufanda.mp4
# 15/11/2020  19:19         1.566.689 legumbres.csv
# 23/09/2020  20:34             4.810 licencias-de-conducir.csv
# 11/09/2020  22:24         1.569.810 listado_epp_diciembre_2019-srt.xlsx
# 04/06/2020  12:55            50.231 List-of-PE-and-PP-products-subject-to-regulation-20-4-17.pdf
# 14/11/2020  10:19         7.098.638 liver_kidney_expseq.zip
# 25/09/2020  21:32           137.737 llamados-atendidos-abuso-sexual-202008.csv
# 06/06/2020  20:12         1.801.958 Logos_ByTailorBrands.zip
# 06/06/2020  20:12            11.984 LogoSample_ByTailorBrands.jpg
# 01/09/2020  14:51            54.293 Lote Optimo.xlsx
# 02/10/2020  17:16           408.805 Lucas.ipynb
# 08/11/2020  10:25         2.856.735 Maltiplechoy_VERSIÓN22.xlsx
# 08/11/2020  12:08         4.300.938 Man_Gest_Res 3-3-3 (1).pptx
# 07/11/2020  17:35         4.300.938 Man_Gest_Res 3-3-3.pptx
# 09/11/2020  17:06           120.901 Manejo 2do Parcial.pdf
# 08/11/2020  10:25           682.449 MANEJO Y GESTION DE RESIDUOS Y DESPERDICIOS.pdf
# 09/08/2020  19:07         1.376.718 Manual de Instrucciones.pdf
# 09/08/2020  19:14           751.765 Manual de Instrucciones_page-0001.jpg
# 15/11/2020  23:20           949.841 Mapa de oportunidades comerciales.pdf
# 23/09/2020  20:25         5.514.456 mapa-manzanas.csv
# 22/04/2020  13:20        65.394.435 Marcos Mundstock.mp4
# 07/04/2020  22:59         1.578.787 Mario 7in1_e65f7499.exe
# 02/04/2020  19:31            15.594 Más de tres sacudidas es paja. Socrates.jpg
# 03/10/2020  21:04             3.541 mi_bici_tu_bici_mensual.csv
# 14/11/2020  17:19            99.233 Mica.ipynb
# 28/11/2019  21:29    <DIR>          Microsoft.SkypeApp_kzf8qxf38zg5c!App
# 28/03/2020  21:09         2.863.343 MODIFICACION INCENDIO SPARKLING.2 dwg.dwg
# 14/10/2020  22:19           497.520 Módulo 1 - Metalmecánica Tecspray.pdf
# 26/06/2020  18:49         1.187.723 MODULO 1 - para imprimir.pdf
# 14/10/2020  22:19           224.085 Módulo 2 - Metalmecánica Tecspray.pdf
# 26/06/2020  18:49           462.682 MODULO 2.pdf
# 26/06/2020  18:50           793.716 MODULO 3.pdf
# 13/07/2020  19:22           760.957 MODULO 4  (1).pdf
# 26/06/2020  18:50           760.957 MODULO 4 .pdf
# 12/11/2020  23:29    <DIR>          Modulo 5
# 17/07/2020  18:01         3.318.581 Módulos Comex Compilados.pdf
# 15/06/2020  20:50            64.142 MOJARRITAS ETAPA X.docx
# 02/02/2018  09:56     1.127.500.666 molinetes_2017.csv
# 22/08/2020  10:29        89.302.448 molinetes-2017.zip
# 26/09/2020  09:38        19.563.608 MSetup_x64.exe
# 08/11/2020  10:25           190.868 Multiple Choise 1er parcial (1).pdf
# 08/11/2020  10:25            19.978 Multiple Choise 1er parcial.docx
# 12/06/2020  09:31           535.032 Multiple Choise 1er parcial.pdf
# 15/11/2020  21:22         3.464.459 nacidos-vivos-registrados-2018_deis (1).csv
# 29/10/2020  19:20         3.464.459 nacidos-vivos-registrados-2018_deis.csv
# 02/06/2020  11:53        16.271.824 NC 2020_v2.xlsx
# 02/06/2020  11:48         4.287.850 NDC Mayo.xls
# 27/06/2017  16:34           247.501 oB3q7PZ.jpg
# 23/04/2020  20:48            18.748 Objetivo B - DP.docx
# 09/12/2017  18:43         2.185.417 obsolescencia-programada-cursoUCS.pdf
# 24/10/2020  10:39        12.110.409 omw.zip
# 23/09/2020  20:37           116.868 operativos.csv
# 23/09/2020  20:43           265.227 operativos-2006.csv
# 23/09/2020  20:43           299.847 operativos-2007.csv
# 01/10/2020  21:42        43.045.069 PEATONES_2019.csv
# 03/10/2020  19:29        21.568.219 PEATONES_2019.xlsx
# 01/10/2020  23:09        45.184.628 PEATONES_2019_V2.csv
# 29/09/2020  21:07         4.721.080 PEATONES_2020.csv
# 25/09/2020  21:23           117.967 personas_2011.csv.crdownload
# 25/09/2020  21:24           273.615 personas_2012.csv (1).crdownload
# 25/09/2020  21:24           445.647 personas_2012.csv (2).crdownload
# 25/09/2020  21:18           208.079 personas_2012.csv.crdownload
# 25/09/2020  21:19           457.935 personas_2016.csv.crdownload
# 25/09/2020  21:14           335.055 personas_2018.csv (1).crdownload
# 25/09/2020  21:13            60.598 personas_2018.csv.crdownload
# 17/06/2020  20:23            51.516 Plan de Vtas_V2.xlsx
# 14/04/2020  21:33           117.882 planos-casa-para-perro-en-dwg-56231.zip
# 27/04/2020  14:08    <DIR>          Plastic Support
# 27/04/2020  12:25        14.257.326 Plastic Support.zip
# 17/02/2020  21:45            68.289 PMO - Descripción de puesto.docx
# 18/11/2020  19:29           432.132 Poster_Grupo11 (1).pdf
# 17/11/2020  20:50           432.132 Poster_Grupo11.pdf
# 17/02/2020  22:30            86.528 PPS3.doc
# 03/03/2020  16:40            86.528 PPS4 (1).doc
# 03/03/2020  16:30            82.944 PPS4.doc
# 14/07/2020  16:14           255.173 PRACTICA COMEX VIRTUAL (con ejemplos).pdf
# 26/09/2020  13:01           469.251 Practica_clase05_regresion_airbnb_london.ipynb
# 18/09/2020  19:13         3.385.094 -Pre Read- (1).pdf
# 18/09/2020  19:12         3.385.094 -Pre Read-.pdf
# 01/05/2020  13:25         3.010.605 Pre-factibilidad (1).pptx
# 22/06/2020  10:17            27.397 Preguntas 1° Parcial.docx
# 08/11/2020  10:25            25.525 Preguntas Clásicas del Pelado.docx
# 07/06/2020  19:54            14.288 Preguntas mo_dulo 1.docx
# 31/05/2020  14:09            12.281 Preguntas módulo 1.docx
# 08/11/2020  09:51         3.696.388 Preguntas unidad 10.pdf
# 08/11/2020  09:51         1.222.079 Preguntas Unidad 6.pdf
# 08/11/2020  09:51         1.877.125 Preguntas unidad 7.pdf
# 08/11/2020  09:51         5.114.107 Preguntas unidad 8.pdf
# 08/11/2020  09:51         3.017.190 Preguntas unidad 9.pdf
# 26/05/2020  20:57           195.063 PRESENTACION de LA CATEDRA de PROYECTO FINAL 2020 (1).pptx
# 16/05/2020  21:00           195.063 PRESENTACION de LA CATEDRA de PROYECTO FINAL 2020.pptx
# 23/02/2020  23:53         1.668.285 Presentación SDP 2018- 2019 (1).pptx
# 17/02/2020  21:46         1.668.285 Presentación SDP 2018- 2019.pptx
# 18/11/2020  20:16           735.528 Presentacion TP ClusterAI.pptx
# 18/06/2020  12:37            73.053 Presupuesto- Nº 712 Sr Sabini - Round Trip Terminal CABA - Moreno - 3° Q 2020.pdf
# 29/10/2020  22:39           101.039 PRESUPUESTO_GASTOS_AREAS_2017.csv
# 10/06/2020  10:01         8.772.843 PRIMER PARCIAL MANEJO.docx
# 08/04/2020  18:51            14.982 Problemas - DP.docx
# 08/11/2020  09:09           870.549 Problemas Resueltos.pdf
# 20/05/2020  20:58        30.064.513 Procyon.zip
# 25/09/2020  21:19        18.217.980 produccin-de-gas-anterior-al-2009.csv
# 15/09/2020  13:33           405.083 Productividad 10-9.xlsx
# 31/03/2020  19:49         4.066.695 Proyecto final - Grupo 8 (1).pdf
# 19/09/2020  20:57             8.712 Puestos.xlsx
# 29/09/2020  19:27           536.976 ReceiverUpdaterCertWindows.exe
# 12/06/2020  11:46         3.032.382 Repaso 2020.pdf
# 01/05/2020  13:39           908.316 report-astor-palermo.pdf
# 09/11/2020  17:37         1.178.742 RESPUESTAS.docx (1).pdf
# 08/11/2020  10:05         1.178.742 RESPUESTAS.docx.pdf
# 08/11/2020  17:18            26.013 Resultados 1er Recuperatorio Viernes CDG.xlsx
# 15/10/2020  23:11        12.108.203 resultados-elecciones-autonomicas-1-2007.csv
# 13/11/2020  18:22         1.349.589 Resumen 2P - MS.pdf
# 08/11/2020  10:25         5.043.877 Resumen Final Manejo 2do Parcial.pdf
# 30/03/2020  18:28         2.641.771 resumen manejo - u1.pdf
# 09/11/2020  10:48        54.832.351 Resumen Manejo de Materiales - 2do Parcial - 2020 (1).pdf
# 09/11/2020  17:21        55.459.036 Resumen Manejo de Materiales - 2do Parcial - 2020 (2).pdf
# 07/11/2020  15:02        47.250.389 Resumen Manejo de Materiales - 2do Parcial - 2020.pdf
# 08/06/2020  09:59        31.539.855 resumen manejo.pdf
# 02/11/2020  18:05           450.823 Resumen P2.docx
# 14/07/2020  16:01           579.438 Resumen primer parcial COMEX.pdf
# 14/07/2020  16:01           743.374 Resumen segundo parcial COMEX.pdf
# 10/08/2020  19:03         1.072.246 Resumen.docx
# 08/11/2020  12:08         4.557.755 RICARDO-GESTION DE RESIDUOS DESPERDICIOS y MATERIALES PELIGROSOS (1).pptx
# 07/11/2020  17:35         4.557.755 RICARDO-GESTION DE RESIDUOS DESPERDICIOS y MATERIALES PELIGROSOS.pptx
# 26/05/2020  09:37         4.640.766 rus2012.pdf
# 22/06/2020  16:17         6.432.029 Scan 22 jun. 2020.pdf
# 04/08/2020  23:03           449.916 Scan 4 ago. 2020 (1).pdf
# 04/08/2020  23:03         2.604.230 Scan 4 ago. 2020.pdf
# 18/06/2020  18:49           236.422 Screenshot_20200613-101935_Chrome.jpg
# 17/02/2020  21:46            10.468 SDP - Recursos humanos, responsabilidades y habilidades.docx
# 17/02/2020  21:46         2.340.638 SDP 2019 _ Culligan Argentina - Third Pass.pptx
# 02/11/2020  18:05           424.688 Segundo parcial mantenimiento (1).docx
# 02/11/2020  18:05           418.035 Segundo parcial mantenimiento.docx
# 21/08/2020  23:07    <DIR>          setup_python-master
# 21/08/2020  22:40           551.135 setup_python-master.zip
# 17/02/2020  21:45           170.852 Sistema de gestión de proyectos.docx
# 01/06/2020  10:05           139.828 SISTEMAS DE METALIZADO.docx
# 07/04/2020  22:55         1.850.086 snes9x-1.54.1-64 bits - JeremyTV.zip
# 07/04/2020  22:45         3.854.525 snes9x-1.60-win32-x64 (1).zip
# 07/04/2020  22:18         3.854.525 snes9x-1.60-win32-x64.zip
# 24/10/2020  10:38            23.047 stopwords.zip
# 11/07/2020  17:44            15.609 tABLAS DE GRAN UTILIDAD.xlsx
# 09/08/2020  12:07           287.019 Tapa USB.png
# 19/05/2020  11:45           344.738 TAREA Clase 11-05-2020 - Con Respuestas.pdf
# 18/05/2020  09:43           258.917 TAREA Clase 11-05-2020.pdf
# 14/04/2020  19:01        27.347.176 TeamViewer_Setup.exe
# 13/11/2020  18:39        10.469.955 Teoria Comex 2do Parcial.pdf
# 05/04/2020  20:01         5.564.933 TESIS 24.03 MEDIODIA (1).docx
# 05/04/2020  20:25         5.412.631 TESIS 24.03 MEDIODIA.docx
# 16/10/2020  17:44           451.405 test.csv
# 25/04/2017  19:23         7.368.965 TL-WN721N_V1_140915.zip
# 25/04/2017  19:34        21.878.929 TL-WN722N(ES)_V2_170125_Windows.zip
# 01/10/2020  23:20        47.365.625 TP CIENCIAS.csv
# 21/06/2020  16:01           806.428 TP N°1 - Grupo 4.pdf
# 09/11/2020  10:15           344.775 TP N°2 - Grupo 4.pdf
# 11/09/2020  19:41            52.262 Tp Negociación (2).docx
# 30/07/2020  23:00         7.322.710 TP Pallets de plastico a MX.docx
# 01/10/2020  23:51        47.532.521 TP_CdD.csv
# 12/10/2020  18:41           219.863 TP_NAC (1).ipynb
# 12/10/2020  20:52           229.644 TP_NAC (2).ipynb
# 03/10/2020  22:32           176.809 TP_NAC.ipynb
# 21/04/2020  23:43           994.446 TP1 Manejo de Materiales (1).pdf
# 07/05/2020  19:19           574.357 TP1 Manejo de Materiales corregido.2 (1).pdf
# 07/05/2020  19:04           574.357 TP1 Manejo de Materiales corregido.2.pdf
# 20/04/2020  10:08           617.549 TP1 Manejo de Materiales.docx
# 21/04/2020  23:40           994.446 TP1 Manejo de Materiales.pdf
# 12/09/2020  20:49           920.981 TP2 - Grupo 2 - Manejo de los Materiales.pdf
# 23/10/2020  21:33           926.830 TP2 - Grupo 2 - Manejo de los Materiales-1.pdf
# 01/10/2020  23:58            10.675 TPCdD-Copy1
# 13/04/2020  17:21           701.226 TPNº1 Edificios Industriales.docx
# 07/09/2020  21:10           675.328 TPNº2 Transportadores Aereos a Cadenas.pdf
# 03/11/2020  20:21         9.787.616 Trabajo Comercio Exterior.docx
# 16/10/2020  17:44           460.676 train.csv
# 29/10/2020  22:37             1.082 Transporte_de_viajeros_en_Autobus_por_CCAA.csv
# 29/09/2020  22:46           126.114 tudanca (1).pdf
# 16/09/2020  23:39           126.114 tudanca.pdf
# 07/11/2020  14:32         8.843.413 Unidad 10.pdf
# 13/10/2020  19:03         2.757.755 Unidad 4.1 - 2020.pdf
# 22/10/2020  20:53           390.259 Unidad 4.2 2020.pdf
# 28/10/2020  21:13           465.804 Unidad 6 - Tercerización.pdf
# 10/08/2020  20:47         7.092.159 Unidades primer parcial (1).pdf
# 10/08/2020  19:45         7.092.159 Unidades primer parcial.pdf
# 02/11/2020  18:06         4.658.952 Unidades segundo parcial.pdf
# 23/11/2017  14:45           102.741 Universidad Tecnológica Nacional.docx
# 09/04/2017  22:09            50.176 Valen17.xls
# 14/02/2018  19:16            51.200 ValeNat17.xls
# 15/11/2020  19:20        11.849.559 valores.csv
# 15/08/2020  18:11           422.060 VE2_0150_2 (1).jpg
# 23/09/2020  20:33             1.803 verificacion-tecnica-vehicular.csv
# 21/04/2020  11:04    <DIR>          VP2016FTX64
# 21/04/2020  11:04       505.561.499 VP2016FTX64.rar
# 23/03/2020  19:46    <DIR>          WA
# 23/03/2020  19:43        75.485.806 WA.rar
# 07/05/2020  16:37         1.528.102 WhatsApp Audio 2020-05-07 at 16.26.16 (online-audio-converter.com).mp3
# 04/03/2020  17:55           133.968 WhatsApp Image 2020-03-04 at 17.53.49 (1).pdf
# 04/03/2020  17:54           157.310 WhatsApp Image 2020-03-04 at 17.53.49.jpeg
# 08/11/2020  08:31            89.528 WhatsApp Image 2020-04-14 at 10.57.27.jpeg
# 08/11/2020  08:42            73.449 WhatsApp Image 2020-04-14 at 10.57.28.jpeg
# 08/11/2020  08:42            84.629 WhatsApp Image 2020-04-14 at 10.57.29.jpeg
# 22/05/2020  11:19           342.112 WhatsApp Image 2020-05-22 at 11.17.43.jpeg
# 30/05/2020  16:33            84.752 WhatsApp Image 2020-05-26 at 21.23.11.jpeg
# 28/05/2020  19:12            68.981 WhatsApp Image 2020-05-28 at 19.12.14.jpeg
# 28/05/2020  19:12            64.903 WhatsApp Image 2020-05-28 at 19.12.15 (1).jpeg
# 28/05/2020  19:12            69.476 WhatsApp Image 2020-05-28 at 19.12.15 (2).jpeg
# 28/05/2020  19:34            75.012 WhatsApp Image 2020-05-28 at 19.12.15 (3).jpeg
# 28/05/2020  19:12            45.400 WhatsApp Image 2020-05-28 at 19.12.15.jpeg
# 28/05/2020  19:27            73.550 WhatsApp Image 2020-05-28 at 19.24.52.jpeg
# 11/06/2020  21:02            83.614 WhatsApp Image 2020-06-11 at 18.40.52.jpeg
# 28/06/2020  17:31           127.890 WhatsApp Image 2020-06-26 at 12.11.53.jpeg
# 14/07/2020  16:01           187.161 WhatsApp Image 2020-07-11 at 18.35.45.jpeg
# 04/08/2020  22:16            41.459 WhatsApp Image 2020-08-04 at 14.28.35.jpeg
# 04/08/2020  22:14           176.845 WhatsApp Image 2020-08-04 at 20.39.13.jpeg
# 16/08/2020  20:03           155.021 WhatsApp Image 2020-08-15 at 19.05.39.jpeg
# 18/08/2020  11:27            53.483 WhatsApp Image 2020-08-18 at 11.27.47.jpeg
# 16/09/2020  16:45           129.060 WhatsApp Image 2020-09-16 at 16.43.52.jpeg
# 16/09/2020  16:45           122.839 WhatsApp Image 2020-09-16 at 16.43.53.jpeg
# 16/09/2020  16:54           114.270 WhatsApp Image 2020-09-16 at 16.53.49 (1).jpeg
# 16/09/2020  16:54           118.980 WhatsApp Image 2020-09-16 at 16.53.49.jpeg
# 01/11/2020  10:47           134.998 WhatsApp Image 2020-11-01 at 10.46.56.jpeg
# 02/11/2020  10:26            63.168 WhatsApp Image 2020-11-01 at 12.36.07.jpeg
# 02/11/2020  10:26            56.018 WhatsApp Image 2020-11-01 at 12.37.17.jpeg
# 02/11/2020  19:08            73.194 WhatsApp Image 2020-11-02 at 19.07.56.jpeg
# 02/11/2020  21:40            77.606 WhatsApp Image 2020-11-02 at 21.40.25.jpeg
# 08/11/2020  09:05           175.681 WhatsApp Image 2020-11-08 at 08.58.15 (1).jpeg
# 08/11/2020  09:05           175.681 WhatsApp Image 2020-11-08 at 08.58.15.jpeg
# 08/11/2020  09:05           136.860 WhatsApp Image 2020-11-08 at 08.58.16.jpeg
# 13/11/2020  19:59            97.157 WhatsApp Image 2020-11-13 at 19.59.13 (1).jpeg
# 13/11/2020  20:00           187.688 WhatsApp Image 2020-11-13 at 19.59.13.jpeg
# 24/10/2020  12:56       141.524.400 WhatsAppSetup.exe
# 15/04/2020  16:01         3.879.351 WhDkC0uT7rU43QLy.mp4
# 21/09/2020  22:05         1.594.400 WirelessSetupHelper1.3.6_es.exe
# 15/11/2020  19:18           169.954 yerba-mate.csv
#              467 archivos  6.315.655.574 bytes
#               17 dirs  28.268.433.408 bytes libres

# %%
#Importamos el Dataset
nacidos = pd.read_csv(r"C:\Users\vatud\Downloads\nacidos-vivos-registrados-2018_deis (1).csv")

# %%
#Visualizamos las primeras líneas del Dataset
nacidos.head()
# Out:
#    jurisdiccion_de_residencia_id jurisdiccion_de_residencia_nombre  \
# 0                             34                           Formosa
# 1                              2       Ciudad Aut. de Buenos Aires
# 2                              6                      Buenos Aires
# 3                             82                          Santa Fe
# 4                             74                          San Luis
#
#    tipo_de_parto_id tipo_de_parto_nombre  sexo sexo_nombre  \
# 0                 1               Simple     2       Mujer
# 1                 1               Simple     1       Varón
# 2                 1               Simple     1       Varón
# 3                 1               Simple     2       Mujer
# 4                 1               Simple     1       Varón
#
#    edad_de_la_madre_grupos_id edad_de_la_madre_grupos_nombre  \
# 0                           4                        25 a 29
# 1                           7                        40 a 44
# 2                           5                        30 a 34
# 3                           6                        35 a 39
# 4                           6                        35 a 39
#
#    semanas_de_gestacion_id semanas_de_gestacion_nombre  \
# 0                        5                     32 a 36
# 1                        6                     37 a 41
# 2                        8             Sin especificar
# 3                        6                     37 a 41
# 4                        5                     32 a 36
#
#    instruccion_de_la_madre_id  instruccion_de_la_madre_nombre  \
# 0                           3        Primaria/C. EGB Completa
# 1                           3        Primaria/C. EGB Completa
# 2                           7  Terciaria/Universitaria Comple
# 3                           7  Terciaria/Universitaria Comple
# 4                           5   Secundaria/Polimodal Completa
#
#    Intervalos_de_peso_al_nacer_id intervalos_de_peso_al_nacer_nombre  \
# 0                               5                        2000 a 2499
# 1                               6                        2500 a 2999
# 2                               4                        1500 a 1999
# 3                               5                        2000 a 2499
# 4                               6                        2500 a 2999
#
#    cantidad_nacimientos
# 0                     3
# 1                    13
# 2                     1
# 3                    30
# 4                     4

# %%
#Vemos cuántas filas y columnas tiene
# Ver que utilizamos la función de numpy "shape".
print("El dataset importado tiene "+ str(np.shape(nacidos)[0]) + " renglones y " + str(np.shape(nacidos)[1]) + " columnas")
# Out:
# El dataset importado tiene 30099 renglones y 15 columnas

# %%
# Verificamos si hay valores nulos en el Dataset
col_nulls = nacidos.isnull().any()
col_nulls
# Out:
# jurisdiccion_de_residencia_id         False
# jurisdiccion_de_residencia_nombre     False
# tipo_de_parto_id                      False
# tipo_de_parto_nombre                  False
# sexo                                  False
# sexo_nombre                           False
# edad_de_la_madre_grupos_id            False
# edad_de_la_madre_grupos_nombre        False
# semanas_de_gestacion_id               False
# semanas_de_gestacion_nombre           False
# instruccion_de_la_madre_id            False
# instruccion_de_la_madre_nombre        False
# Intervalos_de_peso_al_nacer_id        False
# intervalos_de_peso_al_nacer_nombre    False
# cantidad_nacimientos                  False
# dtype: bool

# %%
# Me guardo en un array los nombres de las columnas
columns_nacidos = nacidos.columns
columns_nacidos
# Out:
# Index(['jurisdiccion_de_residencia_id', 'jurisdiccion_de_residencia_nombre',
#        'tipo_de_parto_id', 'tipo_de_parto_nombre', 'sexo', 'sexo_nombre',
#        'edad_de_la_madre_grupos_id', 'edad_de_la_madre_grupos_nombre',
#        'semanas_de_gestacion_id', 'semanas_de_gestacion_nombre',
#        'instruccion_de_la_madre_id', 'instruccion_de_la_madre_nombre',
#        'Intervalos_de_peso_al_nacer_id', 'intervalos_de_peso_al_nacer_nombre',
#        'cantidad_nacimientos'],
#       dtype='object')

# %%
#Vamos a ver los valores que tenemos en cada columna

for i in range(14):
        print('La columna '+ str(columns_nacidos[i])+' tiene '+ str(len(nacidos[columns_nacidos[i]].unique()))+' valores distintos')
        print('Los valores son: \n'+str(nacidos[columns_nacidos[i]].unique())+'\n')
# Out:
# La columna jurisdiccion_de_residencia_id tiene 26 valores distintos
# Los valores son:
# [34  2  6 82 74 99 66 58 62 54 90 78 10 86 22 46 42 38 30 50 26 18 14 70
#  94 98]
#
# La columna jurisdiccion_de_residencia_nombre tiene 26 valores distintos
# Los valores son:
# ['Formosa' 'Ciudad Aut. de Buenos Aires' 'Buenos Aires' 'Santa Fe'
#  'San Luis' 'Lugar no especificado' 'Salta' 'Neuquén' 'Río Negro'
#  'Misiones' 'Tucumán' 'Santa Cruz' 'Catamarca' 'Santiago del Estero'
#  'Chaco' 'La Rioja' 'La Pampa' 'Jujuy' 'Entre Ríos' 'Mendoza' 'Chubut'
#  'Corrientes' 'Córdoba' 'San Juan' 'Tierra del Fuego' 'Otro país']
#
# La columna tipo_de_parto_id tiene 3 valores distintos
# Los valores son:
# [1 2 9]
#
# La columna tipo_de_parto_nombre tiene 3 valores distintos
# Los valores son:
# ['Simple' 'Múltiple' 'Sin especificar']
#
# La columna sexo tiene 4 valores distintos
# Los valores son:
# [2 1 9 3]
#
# La columna sexo_nombre tiene 4 valores distintos
# Los valores son:
# ['Mujer' 'Varón' 'Sin espeficar' 'Indeterminado']
#
# La columna edad_de_la_madre_grupos_id tiene 9 valores distintos
# Los valores son:
# [4 7 5 6 3 2 9 8 1]
#
# La columna edad_de_la_madre_grupos_nombre tiene 9 valores distintos
# Los valores son:
# ['25 a 29' '40 a 44' '30 a 34' '35 a 39' '20 a 24' '15 a 19'
#  'Sin especificar' 'De 45 y más' 'Menor de 15']
#
# La columna semanas_de_gestacion_id tiene 8 valores distintos
# Los valores son:
# [5 6 8 7 3 4 1 2]
#
# La columna semanas_de_gestacion_nombre tiene 8 valores distintos
# Los valores son:
# ['32 a 36' '37 a 41' 'Sin especificar' '42 y más' '24 a 27' '28 a 31'
#  'Menos de 22' '22 a 23']
#
# La columna instruccion_de_la_madre_id tiene 8 valores distintos
# Los valores son:
# [3 7 5 2 8 4 6 1]
#
# La columna instruccion_de_la_madre_nombre tiene 8 valores distintos
# Los valores son:
# ['Primaria/C. EGB Completa' 'Terciaria/Universitaria Comple'
#  'Secundaria/Polimodal Completa' 'Primaria/C. EGB Incompleta'
#  'Sin especificar' 'Secundaria/Polimodal Incomplet'
#  'Terciaria/Universitaria Incomp' 'Sin instrucción']
#
# La columna Intervalos_de_peso_al_nacer_id tiene 9 valores distintos
# Los valores son:
# [5 6 4 7 3 8 9 2 1]
#
# La columna intervalos_de_peso_al_nacer_nombre tiene 9 valores distintos
# Los valores son:
# ['2000 a 2499' '2500 a 2999' '1500 a 1999' '3000 a 3499' '1000 a 1499'
#  'De 3500 y más' 'Sin especificar' '500 a 999' 'Menor de 500']

# %% [markdown]
# ##### Vemos que varias columnas indican 'Sin especificar' es decir no tienen información.  Debemos ver que porcentaje de cada una tiene esta situación para poder tomar una decision.

# %%
#Veo que existen algunas columnas que tienen mal escrito "Sin especificar". Hago el reemplazo
nacidos['sexo_nombre']= nacidos['sexo_nombre'].str.replace('Sin espeficar','Sin especificar')
nacidos['jurisdiccion_de_residencia_nombre']= nacidos['jurisdiccion_de_residencia_nombre'].str.replace('Lugar no especificado','Sin especificar')

# %%
# Creo un Dataframe donde guardaré el % de valores sin especificar para cada columna
sin_esp = pd.DataFrame(columns = ['Column_name','% valores Sin especificar'])

# %%
#Verificamos que porcentaje de valores sin especificar tenemos para cada columna
for t in [1,3,5,7,9,11,13]:
    se = nacidos.loc[nacidos[columns_nacidos[t]] == 'Sin especificar']
    cant = round(((se.shape[0]/nacidos.shape[0])*100),2)
    new_row = {'Column_name':columns_nacidos[t],'% valores Sin especificar': cant}
    sin_esp = sin_esp.append(new_row,ignore_index = True)
sin_esp
# Out:
#                           Column_name  % valores Sin especificar
# 0   jurisdiccion_de_residencia_nombre                       2.15
# 1                tipo_de_parto_nombre                       0.66
# 2                         sexo_nombre                       2.19
# 3      edad_de_la_madre_grupos_nombre                       2.51
# 4         semanas_de_gestacion_nombre                       6.01
# 5      instruccion_de_la_madre_nombre                       8.86
# 6  intervalos_de_peso_al_nacer_nombre                       3.80

# %% [markdown]
# ###### Assumption: Para tener la cantidad de nacidos y no de nacimientos se multiplica la columna que indica el tipo de parto con la de cantidad de nacimientos. Encontramos qeu esta columna tiene algunos valores sin especificar y además la clasificación de tipo de parto, sólo indica "Simple" o "Múltiple". Se supuso lo siguiente:
#
# - Los valores sin especificar corresponden a nacimientos Simples
# - Los nacimientos múltiples corresponden a nacimientos de dos bebés y no más.

# %%
#Se sacan del dataset los datos que no indican la jurisdicción de residencia.
nacidos=nacidos.drop(nacidos[nacidos["jurisdiccion_de_residencia_nombre"] == 'Sin especificar'].index)

# %%
#Asumo que siempre que "Tipo_de_parto_nombre" sea sin especificar será un nacimiento simple.
nacidos['tipo_de_parto_id'].replace('9', 1, inplace = True )
nacidos['tipo_de_parto_nombre'].replace('Sin especificar', 'Simple', inplace = True )

# %%
#Agregamos una columna con la cantidad real de bebés nacidos teniendo en cuenta que hay nacimientos múltiples
nacidos['nacidos'] = nacidos['tipo_de_parto_id']*nacidos['cantidad_nacimientos']
nacidos.tail()
# Out:
#        jurisdiccion_de_residencia_id jurisdiccion_de_residencia_nombre  \
# 30094                             18                        Corrientes
# 30095                             34                           Formosa
# 30096                             86               Santiago del Estero
# 30097                              6                      Buenos Aires
# 30098                             70                          San Juan
#
#        tipo_de_parto_id tipo_de_parto_nombre  sexo      sexo_nombre  \
# 30094                 1               Simple     1            Varón
# 30095                 1               Simple     1            Varón
# 30096                 1               Simple     2            Mujer
# 30097                 2             Múltiple     9  Sin especificar
# 30098                 2             Múltiple     2            Mujer
#
#        edad_de_la_madre_grupos_id edad_de_la_madre_grupos_nombre  \
# 30094                           9                Sin especificar
# 30095                           4                        25 a 29
# 30096                           7                        40 a 44
# 30097                           4                        25 a 29
# 30098                           4                        25 a 29
#
#        semanas_de_gestacion_id semanas_de_gestacion_nombre  \
# 30094                        6                     37 a 41
# 30095                        4                     28 a 31
# 30096                        6                     37 a 41
# 30097                        8             Sin especificar
# 30098                        5                     32 a 36
#
#        instruccion_de_la_madre_id instruccion_de_la_madre_nombre  \
# 30094                           3       Primaria/C. EGB Completa
# 30095                           8                Sin especificar
# 30096                           3       Primaria/C. EGB Completa
# 30097                           8                Sin especificar
# 30098                           5  Secundaria/Polimodal Completa
#
#        Intervalos_de_peso_al_nacer_id intervalos_de_peso_al_nacer_nombre  \
# 30094                               8                      De 3500 y más
# 30095                               8                      De 3500 y más
# 30096                               5                        2000 a 2499
# 30097                               9                    Sin especificar
# 30098                               5                        2000 a 2499
#
#        cantidad_nacimientos  nacidos
# 30094                     2        2
# 30095                     1        1
# 30096                     5        5
# 30097                     2        4
# 30098                     4        8

# %%
#Se eliminan las features que tienen los ids de identificación manteniendo las que poseen los nombres.
nacidos_prep=nacidos.drop(['jurisdiccion_de_residencia_id','tipo_de_parto_id','sexo','edad_de_la_madre_grupos_id','instruccion_de_la_madre_id','cantidad_nacimientos','semanas_de_gestacion_id','intervalos_de_peso_al_nacer_nombre'], axis=1)
nacidos_prep
# Out:
#       jurisdiccion_de_residencia_nombre tipo_de_parto_nombre      sexo_nombre  \
# 0                               Formosa               Simple            Mujer
# 1           Ciudad Aut. de Buenos Aires               Simple            Varón
# 2                          Buenos Aires               Simple            Varón
# 3                              Santa Fe               Simple            Mujer
# 4                              San Luis               Simple            Varón
# ...                                 ...                  ...              ...
# 30094                        Corrientes               Simple            Varón
# 30095                           Formosa               Simple            Varón
# 30096               Santiago del Estero               Simple            Mujer
# 30097                      Buenos Aires             Múltiple  Sin especificar
# 30098                          San Juan             Múltiple            Mujer
#
#       edad_de_la_madre_grupos_nombre semanas_de_gestacion_nombre  \
# 0                            25 a 29                     32 a 36
# 1                            40 a 44                     37 a 41
# 2                            30 a 34             Sin especificar
# 3                            35 a 39                     37 a 41
# 4                            35 a 39                     32 a 36
# ...                              ...                         ...
# 30094                Sin especificar                     37 a 41
# 30095                        25 a 29                     28 a 31
# 30096                        40 a 44                     37 a 41
# 30097                        25 a 29             Sin especificar
# 30098                        25 a 29                     32 a 36
#
#        instruccion_de_la_madre_nombre  Intervalos_de_peso_al_nacer_id  nacidos
# 0            Primaria/C. EGB Completa                               5        3
# 1            Primaria/C. EGB Completa                               6       13
# 2      Terciaria/Universitaria Comple                               4        1
# 3      Terciaria/Universitaria Comple                               5       30
# 4       Secundaria/Polimodal Completa                               6        4
# ...                               ...                             ...      ...
# 30094        Primaria/C. EGB Completa                               8        2
# 30095                 Sin especificar                               8        1
# 30096        Primaria/C. EGB Completa                               5        5
# 30097                 Sin especificar                               9        4
# 30098   Secundaria/Polimodal Completa                               5        8
#
# [29453 rows x 8 columns]

# %% [markdown]
# Debido a que nuestro dataset original está "preprocesado" lo que haremos es volver atras y descomponerlo. En nuestro dataset cada linea representa una combinacion de caracteristicas que tienen los niños al nacer y en la ultima feature de la sample indica la cantidad de niños que tienen esas caracteristicas. Lo que buscamos es pasar a un Dataset que contenga un sample por cada recien nacido. (Esta linea de codigo puede durar varios minutos, aprox=10min)

# %%
samples = np.shape(nacidos_prep)[0]
n_col= nacidos_prep.shape[1]-1

# %%
for j in range(samples):
    registro_a_repetir = nacidos_prep.iloc[j, :]
    n=nacidos_prep.iloc[j, n_col]-1
    nacidos_prep=nacidos_prep.append(([registro_a_repetir]*n), ignore_index=True)

# %%
nacidos_prep=nacidos_prep.drop(['nacidos'], axis=1)
nacidos_prep.shape
# Out:
# (699486, 7)

# %%
nacidos_prep.head()
# Out:
#   jurisdiccion_de_residencia_nombre tipo_de_parto_nombre sexo_nombre  \
# 0                           Formosa               Simple       Mujer
# 1       Ciudad Aut. de Buenos Aires               Simple       Varón
# 2                      Buenos Aires               Simple       Varón
# 3                          Santa Fe               Simple       Mujer
# 4                          San Luis               Simple       Varón
#
#   edad_de_la_madre_grupos_nombre semanas_de_gestacion_nombre  \
# 0                        25 a 29                     32 a 36
# 1                        40 a 44                     37 a 41
# 2                        30 a 34             Sin especificar
# 3                        35 a 39                     37 a 41
# 4                        35 a 39                     32 a 36
#
#    instruccion_de_la_madre_nombre  Intervalos_de_peso_al_nacer_id
# 0        Primaria/C. EGB Completa                               5
# 1        Primaria/C. EGB Completa                               6
# 2  Terciaria/Universitaria Comple                               4
# 3  Terciaria/Universitaria Comple                               5
# 4   Secundaria/Polimodal Completa                               6

# %%
nacidos_prep.to_csv (r'C:\Users\60065215\Desktop\Facultad\Ciencia de Datos\TP Grupal\TP\export_nacidos_dummies.csv', index = False, header=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-ae84d503a080> in <module>
# ----> 1 nacidos_prep.to_csv (r'C:\Users\60065215\Desktop\Facultad\Ciencia de Datos\TP Grupal\TP\export_nacidos_dummies.csv', index = False, header=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     182             close = False
#     183         else:
# --> 184             f, handles = get_handle(
#     185                 self.path_or_buf,
#     186                 self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\60065215\\Desktop\\Facultad\\Ciencia de Datos\\TP Grupal\\TP\\export_nacidos_dummies.csv'

# %% [markdown]
# ## **Machine Learning**

# %%
nacidos_prep = pd.read_csv('export_nacidos_dummies.csv')
nacidos_prep

# %% [markdown]
# Lo que se buscara realizar en este apartado es entrenar un modelo que permita predecir con algunos parametros el peso con el que nacen los bebes.

# %% [markdown]
# Dado que todas las variables presentes en el dataset son categóricas se buscará la creación de Dummies Features para entrenar los modelos.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
# %matplotlib inline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# En primera instancia se limpian los registros que no poseen información e indican "Sin especificar" y se asignan las labels de bajo peso o peso normal.

# %%
nacidos_ML=nacidos_prep
nacidos_ML=nacidos_ML.drop(nacidos_ML[nacidos_prep["sexo_nombre"] == "Sin especificar"].index)
nacidos_ML=nacidos_ML.drop(nacidos_ML[nacidos_prep["edad_de_la_madre_grupos_nombre"] == "Sin especificar"].index)
nacidos_ML=nacidos_ML.drop(nacidos_ML[nacidos_prep["semanas_de_gestacion_nombre"] == "Sin especificar"].index)
nacidos_ML=nacidos_ML.drop(nacidos_ML[nacidos_prep["instruccion_de_la_madre_nombre"] == "Sin especificar"].index)
nacidos_ML=nacidos_ML.drop(nacidos_ML[nacidos_prep["Intervalos_de_peso_al_nacer_id"] == 9].index)
nacidos_ML=nacidos_ML.drop('jurisdiccion_de_residencia_nombre',axis=1)
nacidos_ML

# %%
#Vamos a hacer una clasificacion binaria del peso dividiendo entre bajo y normal
bins = (0, 6.5, 10)
group_names = ['Bajo', 'Normal']
nacidos_ML['Intervalos_de_peso_al_nacer_id'] = pd.cut(nacidos_ML['Intervalos_de_peso_al_nacer_id'], bins = bins, labels = group_names)
#Ahora utilizamos el encoder de sklearn
label_quality = LabelEncoder() #from sklearn.preprocessing, sirve para transformar los valores entre 0 y n_clases-1
#Bajo es 0 y Normal es 1 
nacidos_ML['Intervalos_de_peso_al_nacer_id'] = label_quality.fit_transform(nacidos_ML['Intervalos_de_peso_al_nacer_id'])
nacidos_ML['Intervalos_de_peso_al_nacer_id'].value_counts()

# %% [markdown]
# Como podemos observar solo el 26% de los bebes nacen con un peso bajo. Esto podria generar un problema a la hora de entrenar debido que nuestro modelo estara entrenado con muchos mas samples de bebes que tienen un peso adecuado frente a los que tienen dicho problema.

# %%
nacidos_ML.head()

# %%
#Genero Dummies para todas las features que utilizaré como independientes
tipo_parto = pd.get_dummies(nacidos_ML.tipo_de_parto_nombre)
sexo = pd.get_dummies(nacidos_ML.sexo_nombre)
edad_madre = pd.get_dummies(nacidos_ML.edad_de_la_madre_grupos_nombre)
gestacion = pd.get_dummies(nacidos_ML.semanas_de_gestacion_nombre)
instruccion = pd.get_dummies(nacidos_ML.instruccion_de_la_madre_nombre)

# %%
#Concateno el dataframe original con el dataframe generado con dummies
nacidos_dummies = pd.concat([nacidos_ML,tipo_parto, sexo, edad_madre, gestacion, instruccion], axis=1)
nacidos_dummies = nacidos_dummies.drop(['tipo_de_parto_nombre','sexo_nombre','edad_de_la_madre_grupos_nombre','semanas_de_gestacion_nombre','instruccion_de_la_madre_nombre'], axis = 1)
nacidos_dummies

# %% [markdown]
# Por la cantidad de recursos de computo que se requieren para realizar el aprendizaje con mas de 600000 samples, decidimos solo entrenar con 5000 elegidas al azar dentro del Dataset.

# %%
nacidos_muestra = nacidos_dummies.sample(n=5000, axis=0, random_state=13)
nacidos_muestra.shape

# %% [markdown]
# De esas 5000 las etiquetas que aparecen son las siguientes.

# %%
nacidos_muestra['Intervalos_de_peso_al_nacer_id'].value_counts()

# %% [markdown]
# ## Clasificación de los pesos

# %% [markdown]
# Dividimos en Train y test, scalamos y entrenamos con diferentes modelos.
# Los Features con las que entrenaremos son:
#
# *   Edad de la madre
# *   Semana de gestacion a la hora de nacer
# *   Instruccion de la madre
# *   Sexo
# *   Tipo de parto

# %%
X = nacidos_muestra.drop('Intervalos_de_peso_al_nacer_id', axis = 1)
y = nacidos_muestra['Intervalos_de_peso_al_nacer_id']

# %%
#Separamos en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.5, random_state = 14)

# %%
#Aplicamos standard scaler para optimizar los resultados
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %% [markdown]
# #### SVM

# %%
#Buscamos mejores parametros usando CV
svc = SVC()
param = {
    'C': [1, 10, 100, 1000],
    'kernel':['rbf'],
    'gamma' :[0.0001,0.001, 0.01, 0.1,1, 10,100]
}
grid_svc = GridSearchCV(svc, param_grid=param, scoring='accuracy', cv=4)
grid_svc.fit(X_train, y_train)

# %%
grid_svc.best_params_

# %%
pred_svc_cv =grid_svc.predict(X_test)
print(classification_report(y_test, pred_svc_cv))

# %%
cm_svm_gs =confusion_matrix(y_test, pred_svc_cv)
confmat = pd.DataFrame(cm_svm_gs, index = ['Bajo', 'Normal'], columns = ['Bajo', 'Normal'])
plt.figure(figsize = (6,4))
sns.heatmap(confmat, annot=True,cmap='YlGnBu', fmt="d")
plt.title('Matriz de Confusion SVM+CV')
plt.show()

# %%
cm_svm_gs

# %% [markdown]
# #### Metodo KNN

# %%
parameters = {'n_neighbors':[1, 3, 5, 10, 25, 50]}
knn = KNeighborsClassifier()
clf_knn = GridSearchCV(knn, param_grid = parameters, refit= True, cv = 5)

clf_knn.fit(X_train, y_train)
ypred_knn_gs=clf_knn.predict(X_test)

# %%
print(classification_report(y_test, ypred_knn_gs))

# %% [markdown]
# Hacemos una matriz de confusion para ver los resultados obtenidos, armamos un reporte y vemos con cuantos K vecinos se obtuvieron los mejores resultados.

# %%
#cantidad de vecinos
clf_knn.best_params_

# %%
cm_knn = confusion_matrix(y_test, ypred_knn_gs)
confmat = pd.DataFrame(cm_knn, index = ['Bajo', 'Normal'], columns = ['Bajo', 'Normal'])
plt.figure(figsize = (6,4))
sns.heatmap(confmat, annot=True,cmap='YlGnBu', fmt="d")
plt.title('Matriz de confusion KNN+CV')
plt.show()

# %%
cm_knn_gs
# Out:
# array([[ 305,  681],
#        [  57, 2707]], dtype=int64)

# %% [markdown]
# #### Logistic Regresion

# %%
parameters = {'C':[1, 10, 100, 1000]}
lr_model = LogisticRegression(random_state=0, solver='lbfgs')
clf_lr = GridSearchCV(lr_model, param_grid = parameters, refit = True, cv = 5)

# %%
clf_lr.fit(X_train, y_train)
ypred_lr_gs=clf_lr.predict(X_test)
print(classification_report(y_test, ypred_lr_gs))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.35      0.49       986
#            1       0.81      0.97      0.88      2764
#
#     accuracy                           0.81      3750
#    macro avg       0.82      0.66      0.69      3750
# weighted avg       0.81      0.81      0.78      3750

# %%
cm_lr_gs = confusion_matrix(y_test, ypred_lr_gs)
confmat = pd.DataFrame(cm_lr_gs, index = ['Bajo', 'Normal'], columns = ['Bajo', 'Normal'])
plt.figure(figsize = (6,4))
sns.heatmap(confmat, annot=True,cmap='YlGnBu', fmt="d")
plt.title('Matriz de confusion LR+CV')
plt.show()

# %%
cm_lr_gs
# Out:
# array([[ 342,  644],
#        [  70, 2694]], dtype=int64)
